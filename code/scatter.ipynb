# %%
# Load packages
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import pandas as pd


pio.renderers.default = "plotly_mimetype+notebook_connected"

# %%
# read in data
df = pd.read_csv("../data/combine_data.csv")
df.head()
# Out:
#    Unnamed: 0      Country  year  Happiness Score  Log GDP per capita  \
# 0           0  Afghanistan  2008         3.723590            7.302574
# 1           1  Afghanistan  2009         4.401778            7.472446
# 2           2  Afghanistan  2010         4.758381            7.579183
# 3           3  Afghanistan  2011         3.831719            7.552006
# 4           4  Afghanistan  2012         3.782938            7.637953
#
#    Social support     Health  Freedom to make life choices  Generosity  \
# 0        0.450662  50.500000                      0.718114    0.173169
# 1        0.552308  50.799999                      0.678896    0.195469
# 2        0.539075  51.099998                      0.600127    0.125859
# 3        0.521104  51.400002                      0.495901    0.167723
# 4        0.520637  51.700001                      0.530935    0.241247
#
#    Corruption  ...  Negative affect  Confidence in national government  \
# 0    0.881686  ...         0.258195                           0.612072
# 1    0.850035  ...         0.237092                           0.611545
# 2    0.706766  ...         0.275324                           0.299357
# 3    0.731109  ...         0.267175                           0.307386
# 4    0.775620  ...         0.267919                           0.435440
#
#    continent Country Code Time Code CO2 emissions  Population  Unemployment  \
# 0       Asia          AFG    YR2008   3559.999943  26427199.0          2.49
# 1       Asia          AFG    YR2009   4880.000114  27385307.0           NaN
# 2       Asia          AFG    YR2010   7110.000134  28189672.0           NaN
# 3       Asia          AFG    YR2011   8930.000305  29249157.0           NaN
# 4       Asia          AFG    YR2012   8079.999924  30466479.0          1.69
#
#    Children out of school  Adjusted net national income
# 0                     NaN                           NaN
# 1                     NaN                  1.129747e+10
# 2                     NaN                  1.448363e+10
# 3                     NaN                  1.626732e+10
# 4                     NaN                  1.822551e+10
#
# [5 rows x 21 columns]

# %%
# Plot scatter plot
fig = px.scatter(df, x="Happiness Score", 
                   y="Freedom to make life choices", 
                   color="continent", 

                   # Add trendline in scatter plot
                   trendline="ols",

                   # Plot boxplot for x and y
                   marginal_x="box", 
                   marginal_y="box",

                   # Change legend order
                   category_orders={"continent": ["Oceania", "North America", "Europe", "South America", "Asia","Africa"]},
                   
                   # Set color for each continent
                   color_discrete_sequence=["rgb(166, 216, 84)", "rgb(231, 138, 195)", "rgb(141, 160, 203)", "rgb(255, 217, 47)", "rgb(252, 141, 98)", "rgb(102, 194, 165)"]
                   )

# Update layout
# Set template, height, and write title, X and Y axis title
fig.update_layout(template="plotly_white",
                  height=600,
                  title="Happiness Score vs Freedom to Make Life Choice",
                  xaxis_title="Happiness Score",
                  yaxis_title="Freedom",
                  legend_title_text = "Continent"
                  )

# Show plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d2e0f335-c2a3-4582-a3e1-8dd57a8bf887" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2e0f335-c2a3-4582-a3e1-8dd57a8bf887")) {                    Plotly.newPlot(                        "d2e0f335-c2a3-4582-a3e1-8dd57a8bf887",                        [{"hovertemplate":"continent=Oceania<br>Happiness Score=%{x}<br>Freedom to make life choices=%{y}<extra></extra>","legendgroup":"Oceania","marker":{"color":"rgb(166, 216, 84)","symbol":"circle"},"mode":"markers","name":"Oceania","showlegend":true,"x":[7.253757476806641,7.450047016143799,7.405616283416748,7.19558572769165,7.364169120788574,7.28855037689209,7.309060573577881,7.250080108642578,7.25703763961792,7.176993370056152,7.233994960784912,7.1373677253723145,7.111598968505859,7.381170749664307,7.223756313323975,7.190638065338135,7.249629974365234,7.280151844024658,7.305892467498779,7.418120861053467,7.225687980651855,7.327182769775391,7.370285987854004,7.205174446105957,7.257381916046143,7.136700630187988],"xaxis":"x","y":[0.9157333374023438,0.932058572769165,0.944586455821991,0.9351462721824646,0.9333791732788086,0.922932267189026,0.9218710064888,0.9223157167434692,0.9105501770973206,0.9160281419754028,0.9175369143486024,0.905282974243164,0.9124022126197816,0.8930724859237671,0.9177525043487548,0.9347687363624572,0.901853084564209,0.9440004229545592,0.9318824410438538,0.9417842626571656,0.9265760183334352,0.9422794580459596,0.9493001699447632,0.9120423793792723,0.9181545972824096,0.9102498292922974],"yaxis":"y","type":"scattergl"},{"alignmentgroup":"True","hovertemplate":"continent=Oceania<br>Happiness Score=%{x}<extra></extra>","legendgroup":"Oceania","marker":{"color":"rgb(166, 216, 84)","symbol":"circle"},"name":"Oceania","notched":true,"offsetgroup":"Oceania","showlegend":false,"x":[7.253757476806641,7.450047016143799,7.405616283416748,7.19558572769165,7.364169120788574,7.28855037689209,7.309060573577881,7.250080108642578,7.25703763961792,7.176993370056152,7.233994960784912,7.1373677253723145,7.111598968505859,7.381170749664307,7.223756313323975,7.190638065338135,7.249629974365234,7.280151844024658,7.305892467498779,7.418120861053467,7.225687980651855,7.327182769775391,7.370285987854004,7.205174446105957,7.257381916046143,7.136700630187988],"xaxis":"x3","yaxis":"y3","type":"box"},{"alignmentgroup":"True","hovertemplate":"continent=Oceania<br>Freedom to make life choices=%{y}<extra></extra>","legendgroup":"Oceania","marker":{"color":"rgb(166, 216, 84)","symbol":"circle"},"name":"Oceania","notched":true,"offsetgroup":"Oceania","showlegend":false,"xaxis":"x2","y":[0.9157333374023438,0.932058572769165,0.944586455821991,0.9351462721824646,0.9333791732788086,0.922932267189026,0.9218710064888,0.9223157167434692,0.9105501770973206,0.9160281419754028,0.9175369143486024,0.905282974243164,0.9124022126197816,0.8930724859237671,0.9177525043487548,0.9347687363624572,0.901853084564209,0.9440004229545592,0.9318824410438538,0.9417842626571656,0.9265760183334352,0.9422794580459596,0.9493001699447632,0.9120423793792723,0.9181545972824096,0.9102498292922974],"yaxis":"y2","type":"box"},{"hovertemplate":"<b>OLS trendline</b><br>Freedom to make life choices = 0.0767484 * Happiness Score + 0.36568<br>R<sup>2</sup>=0.226238<br><br>continent=Oceania<br>Happiness Score=%{x}<br>Freedom to make life choices=%{y} <b>(trend)</b><extra></extra>","legendgroup":"Oceania","marker":{"color":"rgb(166, 216, 84)","symbol":"circle"},"mode":"lines","name":"Oceania","showlegend":false,"x":[7.111598968505859,7.136700630187988,7.1373677253723145,7.176993370056152,7.190638065338135,7.19558572769165,7.205174446105957,7.223756313323975,7.225687980651855,7.233994960784912,7.249629974365234,7.250080108642578,7.253757476806641,7.25703763961792,7.25 ...

# %%
# save to html
fig.write_html('../img/scatter.html')
